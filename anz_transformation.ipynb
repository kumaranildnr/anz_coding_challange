# %%
# reading file ANZ_synthesised_transaction_dataset into dataframe 
df_txn = spark.read.format("csv").option("header", "true")\
.option("inferSchema","true").load("dbfs:/FileStore/shared_uploads/anilsjcit@gmail.com/ANZ_synthesised_transaction_dataset.csv")

# %%
# reading file postal_code into dataframe 
df_pc = spark.read.format("csv").option("header", "true")\
.option("inferSchema","true").load("dbfs:/FileStore/shared_uploads/anilsjcit@gmail.com/postal_codes.csv")

# %%
# 
df_txn_auth = df_txn.filter((df_txn['status'] == "authorized") & (df_txn['card_present_flag'] == 0))

# %%
#show the results of Apply rule: Status = “authorized” and card_present_flag=0
df_txn_auth.show(truncate=False)
# Out:
# +----------+-----------------+----------------+--------------+--------+--------------+---------------+------------------------------------+-------------+-----------+---------+--------+------+---+----------------+--------------+-------------------+------+--------------------------------+---------+--------------+-----------------+--------+
# |status    |card_present_flag|bpay_biller_code|account       |currency|long_lat      |txn_description|merchant_id                         |merchant_code|first_name |balance  |date    |gender|age|merchant_suburb |merchant_state|extraction         |amount|transaction_id                  |country  |customer_id   |merchant_long_lat|movement|
# +----------+-----------------+----------------+--------------+--------+--------------+---------------+------------------------------------+-------------+-----------+---------+--------+------+---+----------------+--------------+-------------------+------+--------------------------------+---------+--------------+-----------------+--------+
# |authorized|0                |null            |ACC-1598451071|AUD     |153.41 -27.95 |SALES-POS      |830a451c-316e-4a6a-bf25-e37caedca49e|null         |Diana      |21.2     |01/08/18|F     |26 |Sydney          |NSW           |2018-08-01 01:13:45|14.19 |13270a2a902145da9db4c951e04b51b9|Australia|CUS-2487424745|151.21 -33.87    |debit   |
# |authorized|0                |null            |ACC-2890243754|AUD     |153.32 -27.93 |POS            |7e8bf667-e724-4359-a406-3538a3e27b4e|null         |Joseph     |275.93   |01/08/18|M     |37 |Lismore         |NSW           |2018-08-01 08:19:14|24.77 |1f12467d33ce4609890fb64978ebbcbb|Australia|CUS-2695611575|153.28 -28.81    |debit   |
# |authorized|0                |null            |ACC-2615038700|AUD     |145.35 -38.03 |POS            |354f40cb-55bc-4a81-a00d-c7faede29f8b|null         |Emily      |30583.15 |01/08/18|F     |43 |Mordialloc      |VIC           |2018-08-01 08:47:48|12.08 |49417bad354f4137971a954c26657e2d|Australia|CUS-3255104878|145.09 -38.01    |debit   |
# |authorized|0                |null            |ACC-1710017148|AUD     |150.82 -34.01 |SALES-POS      |4af25042-a1a4-4688-90b5-240d790e5332|null         |Michelle   |1625.34  |01/08/18|F     |19 |Alexandria      |NSW           |2018-08-01 09:11:00|11.57 |82acf03790844776b4587fd6e6f526c5|Australia|CUS-883482547 |151.19 -33.92    |debit   |
# |authorized|0                |null            |ACC-3485804958|AUD     |138.52 -35.01 |POS            |a08935a2-99a8-49f0-b73a-f8de51ca0abd|null         |Jessica    |12529.59 |01/08/18|F     |34 |Findon          |SA            |2018-08-01 09:19:06|33.89 |89050ee5c5aa4e79b03e717518236bf9|Australia|CUS-1196156254|138.53 -34.9     |debit   |
# |authorized|0                |null            |ACC-1799207998|AUD     |150.68 -33.79 |POS            |eb3f245f-1016-416a-bab1-6743f6450d34|null         |Susan      |43.06    |01/08/18|F     |20 |Brookvale       |NSW           |2018-08-01 16:28:40|76.82 |954d5cc3ef1c4dbe96219af4ae7d7b5a|Australia|CUS-164374203 |151.27 -33.77    |debit   |
# |authorized|0                |null            |ACC-3879258709|AUD     |143.83 -37.66 |POS            |d8baa380-1cf2-485e-8b61-e6b73aab3400|null         |Natasha    |186344.95|01/08/18|F     |40 |Ballarat        |VIC           |2018-08-01 16:45:20|26.91 |1eb22646ff724bfb9d3f3b8108abf785|Australia|CUS-527400765 |143.81 -37.55    |debit   |
# |authorized|0                |null            |ACC-854938045 |AUD     |147.63 -22.84 |POS            |a676e908-5124-4f59-b35c-4617dac98872|null         |James      |6941.78  |01/08/18|M     |28 |Junee           |NSW           |2018-08-01 17:01:07|22.59 |77e20a08f52446c3b903a215949968d3|Australia|CUS-4023861240|147.59 -34.86    |debit   |
# |authorized|0                |null            |ACC-90814749  |AUD     |151.68 -32.98 |SALES-POS      |5e4447f8-8083-40eb-b75f-f7e9a0583d3c|null         |Christopher|6022.68  |01/08/18|M     |35 |Peterborough    |SA            |2018-08-01 18:45:07|19.58 |3b8ac93bc7cd4d24a288882782a805e6|Australia|CUS-1896554896|138.84 -32.97    |debit   |
# |authorized|0                |null            |ACC-1598451071|AUD     |153.41 -27.95 |SALES-POS      |73aac058-cb31-46c2-826d-29b161bfb23e|null         |Diana      |995.57   |01/08/18|F     |26 |Elanora         |QLD           |2018-08-01 19:33:51|11.28 |9a13829c885344c3ad6c6f1a2d30d1bc|Australia|CUS-2487424745|153.47 -28.13    |debit   |
# |authorized|0                |null            |ACC-854938045 |AUD     |147.63 -22.84 |SALES-POS      |6ef562a8-928c-4f56-86f1-592357fd5daa|null         |James      |6924.65  |01/08/18|M     |28 |Seven Mile Beach|TAS           |2018-08-01 20:35:47|17.13 |414f37db1e6143fbbf24501ce457c161|Australia|CUS-4023861240|147.5 -42.86     |debit   |
# |authorized|0                |null            |ACC-1598451071|AUD     |153.41 -27.95 |POS            |d87e2b48-3fc5-47e4-87c5-014e56e493df|null         |Diana      |986.58   |01/08/18|F     |26 |Elanora         |QLD           |2018-08-01 21:38:31|8.99  |e1949cb88eb74ad1b0391347a221e938|Australia|CUS-2487424745|153.47 -28.13    |debit   |
# +----------+-----------------+----------------+--------------+--------+--------------+---------------+------------------------------------+-------------+-----------+---------+--------+------+---+----------------+--------------+-------------------+------+--------------------------------+---------+--------------+-----------------+--------+
# only showing top 20 rows

# %%
#Showing results based on group by to verify filter is working as expected
df_txn_auth.groupBy("status").count().show()
# Out:
# +----------+-----+
# |    status|count|
# +----------+-----+
# |authorized| 1523|
# +----------+-----+

# %%
#Showing results based on group by to verify filter is working as expected
df_txn_auth.groupBy("status","card_present_flag").count().show()
# Out:
# +----------+-----------------+-----+
# |    status|card_present_flag|count|
# +----------+-----------------+-----+
# |authorized|                0| 1523|
# +----------+-----------------+-----+

# %%
#Split the long_lat and merchant_long_lat fields for qualified records into long, lat and merch_long, merch_lat fields.
#first lets select few columns from dataframe
df_longlat = df_txn.select("status","account","long_lat","merchant_id","merchant_long_lat")

# %%
#selecting first 15 records
df_longlat.show(15,truncate=False)
# Out:
# +----------+--------------+-------------+------------------------------------+-----------------+
# |status    |account       |long_lat     |merchant_id                         |merchant_long_lat|
# +----------+--------------+-------------+------------------------------------+-----------------+
# |authorized|ACC-1598451071|153.41 -27.95|81c48296-73be-44a7-befa-d053f48ce7cd|153.38 -27.99    |
# |authorized|ACC-1598451071|153.41 -27.95|830a451c-316e-4a6a-bf25-e37caedca49e|151.21 -33.87    |
# |authorized|ACC-1222300524|151.23 -33.94|835c231d-8cdf-4e96-859d-e9d571760cf0|151.21 -33.87    |
# |authorized|ACC-1037050564|153.10 -27.66|48514682-c78a-4a88-b0da-2d6302e64673|153.05 -26.68    |
# |authorized|ACC-1598451071|153.41 -27.95|b4e02c10-0852-4273-b8fd-7b3395e32eb0|153.44 -28.06    |
# |posted    |ACC-1608363396|151.22 -33.87|null                                |null             |
# |authorized|ACC-2776252858|144.95 -37.76|3aa18033-a0a9-4190-a117-b7caaf4d07e3|144.95 -37.53    |
# |authorized|ACC-2776252858|144.95 -37.76|ee58145d-26e8-4b01-9cd9-62378014f21d|144.96 -37.81    |
# |authorized|ACC-182446574 |116.06 -32.00|cfbf535e-caa8-499f-9d41-bbdc2b836d85|115.85 -31.9     |
# |posted    |ACC-602667573 |151.23 -33.96|null                                |null             |
# |posted    |ACC-2171593283|146.94 -36.04|null                                |null             |
# |posted    |ACC-2776252858|144.95 -37.76|null                                |null             |
# |authorized|ACC-182446574 |116.06 -32.00|33952b07-859c-4c0a-8b1d-813a5f6b444c|115.86 -32.13    |
# |posted    |ACC-588564840 |151.27 -33.76|null                                |null             |
# |posted    |ACC-1496451953|145.16 -37.84|null                                |null             |
# +----------+--------------+-------------+------------------------------------+-----------------+
# only showing top 15 rows

# %%
#splitting longitude and latitude details
from pyspark.sql.functions import split
df_split = df_longlat.withColumn('long', split(df_longlat['long_lat'], ' ').getItem(0)) \
                     .withColumn('lat', split(df_longlat['long_lat'], ' ').getItem(1)) \
                     .withColumn('merch_long', split(df_longlat['merchant_long_lat'], ' ').getItem(0)) \
                     .withColumn('merch_lat', split(df_longlat['merchant_long_lat'], ' ').getItem(1))
df_split.show()
# Out:
# +----------+--------------+-------------+--------------------+-----------------+------+------+----------+---------+
# |    status|       account|     long_lat|         merchant_id|merchant_long_lat|  long|   lat|merch_long|merch_lat|
# +----------+--------------+-------------+--------------------+-----------------+------+------+----------+---------+
# |authorized|ACC-1598451071|153.41 -27.95|81c48296-73be-44a...|    153.38 -27.99|153.41|-27.95|    153.38|   -27.99|
# |authorized|ACC-1598451071|153.41 -27.95|830a451c-316e-4a6...|    151.21 -33.87|153.41|-27.95|    151.21|   -33.87|
# |authorized|ACC-1222300524|151.23 -33.94|835c231d-8cdf-4e9...|    151.21 -33.87|151.23|-33.94|    151.21|   -33.87|
# |authorized|ACC-1037050564|153.10 -27.66|48514682-c78a-4a8...|    153.05 -26.68|153.10|-27.66|    153.05|   -26.68|
# |authorized|ACC-1598451071|153.41 -27.95|b4e02c10-0852-427...|    153.44 -28.06|153.41|-27.95|    153.44|   -28.06|
# |    posted|ACC-1608363396|151.22 -33.87|                null|             null|151.22|-33.87|      null|     null|
# |authorized|ACC-2776252858|144.95 -37.76|3aa18033-a0a9-419...|    144.95 -37.53|144.95|-37.76|    144.95|   -37.53|
# |authorized|ACC-2776252858|144.95 -37.76|ee58145d-26e8-4b0...|    144.96 -37.81|144.95|-37.76|    144.96|   -37.81|
# |authorized| ACC-182446574|116.06 -32.00|cfbf535e-caa8-499...|     115.85 -31.9|116.06|-32.00|    115.85|    -31.9|
# |    posted| ACC-602667573|151.23 -33.96|                null|             null|151.23|-33.96|      null|     null|
# |    posted|ACC-2171593283|146.94 -36.04|                null|             null|146.94|-36.04|      null|     null|
# |    posted|ACC-2776252858|144.95 -37.76|                null|             null|144.95|-37.76|      null|     null|
# |authorized| ACC-182446574|116.06 -32.00|33952b07-859c-4c0...|    115.86 -32.13|116.06|-32.00|    115.86|   -32.13|
# |    posted| ACC-588564840|151.27 -33.76|                null|             null|151.27|-33.76|      null|     null|
# |    posted|ACC-1496451953|145.16 -37.84|                null|             null|145.16|-37.84|      null|     null|
# |authorized|ACC-1903037542|153.05 -27.61|d920de7f-959c-4d9...|    152.94 -27.55|153.05|-27.61|    152.94|   -27.55|
# |    posted|ACC-2014856841|144.99 -37.90|                null|             null|144.99|-37.90|      null|     null|
# |    posted|ACC-4163822186|149.03 -34.97|                null|             null|149.03|-34.97|      null|     null|
# |    posted|ACC-3954677887|115.72 -32.28|                null|             null|115.72|-32.28|      null|     null|
# |authorized|ACC-4258502723|145.45 -37.74|b5565fff-0333-4c7...|    144.96 -37.78|145.45|-37.74|    144.96|   -37.78|
# +----------+--------------+-------------+--------------------+-----------------+------+------+----------+---------+
# only showing top 20 rows

# %%
#Join postal reference data to pull the postal code to the output record
#Check few records from postal code csv file
df_pc.show(15,truncate=False)
# Out:
# +----------------+-----+-----------+
# |suburb          |state|postal_code|
# +----------------+-----+-----------+
# |Ashmore         |QLD  |700001     |
# |Sydney          |NSW  |700002     |
# |Buderim         |QLD  |700003     |
# |Mermaid Beach   |QLD  |700004     |
# |Kalkallo        |VIC  |700005     |
# |Melbourne       |VIC  |700006     |
# |Yokine          |WA   |700007     |
# |Cockburn Central|WA   |700008     |
# |Mount Ommaney   |QLD  |700009     |
# |Brunswick       |VIC  |700010     |
# |Byron Bay       |NSW  |700011     |
# |Lismore         |NSW  |700012     |
# |Fremantle       |WA   |700013     |
# |Mordialloc      |VIC  |700014     |
# |Chatswood       |NSW  |700015     |
# +----------------+-----+-----------+
# only showing top 15 rows

# %%
#Do the inner join with field merchant_suburb from df_txn and field suburb from df_pc
df_join = df_txn.join(df_pc,df_txn.merchant_suburb ==  df_pc.suburb,"inner")
df_join.show(truncate=False)
# Out:
# +----------+-----------------+----------------+--------------+--------+-------------+---------------+------------------------------------+-------------+----------+--------+--------+------+---+----------------+--------------+-------------------+------+--------------------------------+---------+--------------+-----------------+--------+----------------+-----+-----------+
# |status    |card_present_flag|bpay_biller_code|account       |currency|long_lat     |txn_description|merchant_id                         |merchant_code|first_name|balance |date    |gender|age|merchant_suburb |merchant_state|extraction         |amount|transaction_id                  |country  |customer_id   |merchant_long_lat|movement|suburb          |state|postal_code|
# +----------+-----------------+----------------+--------------+--------+-------------+---------------+------------------------------------+-------------+----------+--------+--------+------+---+----------------+--------------+-------------------+------+--------------------------------+---------+--------------+-----------------+--------+----------------+-----+-----------+
# |authorized|1                |null            |ACC-1598451071|AUD     |153.41 -27.95|POS            |81c48296-73be-44a7-befa-d053f48ce7cd|null         |Diana     |35.39   |01/08/18|F     |26 |Ashmore         |QLD           |2018-08-01 01:01:15|16.25 |a623070bfead4541a6b0fff8a09e706c|Australia|CUS-2487424745|153.38 -27.99    |debit   |Ashmore         |QLD  |700001     |
# |authorized|0                |null            |ACC-1598451071|AUD     |153.41 -27.95|SALES-POS      |830a451c-316e-4a6a-bf25-e37caedca49e|null         |Diana     |21.2    |01/08/18|F     |26 |Sydney          |NSW           |2018-08-01 01:13:45|14.19 |13270a2a902145da9db4c951e04b51b9|Australia|CUS-2487424745|151.21 -33.87    |debit   |Sydney          |NSW  |700002     |
# |authorized|1                |null            |ACC-1222300524|AUD     |151.23 -33.94|POS            |835c231d-8cdf-4e96-859d-e9d571760cf0|null         |Michael   |5.71    |01/08/18|M     |38 |Sydney          |NSW           |2018-08-01 01:26:15|6.42  |feb79e7ecd7048a5a36ec889d1a94270|Australia|CUS-2142601169|151.21 -33.87    |debit   |Sydney          |NSW  |700002     |
# |authorized|1                |null            |ACC-1037050564|AUD     |153.10 -27.66|SALES-POS      |48514682-c78a-4a88-b0da-2d6302e64673|null         |Rhonda    |2117.22 |01/08/18|F     |40 |Buderim         |QLD           |2018-08-01 01:38:45|40.9  |2698170da3704fd981b15e64a006079e|Australia|CUS-1614226872|153.05 -26.68    |debit   |Buderim         |QLD  |700003     |
# |authorized|1                |null            |ACC-1598451071|AUD     |153.41 -27.95|SALES-POS      |b4e02c10-0852-4273-b8fd-7b3395e32eb0|null         |Diana     |17.95   |01/08/18|F     |26 |Mermaid Beach   |QLD           |2018-08-01 01:51:15|3.25  |329adf79878c4cf0aeb4188b4691c266|Australia|CUS-2487424745|153.44 -28.06    |debit   |Mermaid Beach   |QLD  |700004     |
# only showing top 20 rows

# %%
#select few records to verify join is working fine or not
df_join.select("status","account","long_lat","merchant_id","merchant_long_lat","merchant_suburb","state","postal_code").show(15,truncate=False)
# Out:
# +----------+--------------+-------------+------------------------------------+-----------------+----------------+-----+-----------+
# |status    |account       |long_lat     |merchant_id                         |merchant_long_lat|merchant_suburb |state|postal_code|
# +----------+--------------+-------------+------------------------------------+-----------------+----------------+-----+-----------+
# |authorized|ACC-1598451071|153.41 -27.95|81c48296-73be-44a7-befa-d053f48ce7cd|153.38 -27.99    |Ashmore         |QLD  |700001     |
# |authorized|ACC-1598451071|153.41 -27.95|830a451c-316e-4a6a-bf25-e37caedca49e|151.21 -33.87    |Sydney          |NSW  |700002     |
# |authorized|ACC-1222300524|151.23 -33.94|835c231d-8cdf-4e96-859d-e9d571760cf0|151.21 -33.87    |Sydney          |NSW  |700002     |
# |authorized|ACC-1037050564|153.10 -27.66|48514682-c78a-4a88-b0da-2d6302e64673|153.05 -26.68    |Buderim         |QLD  |700003     |
# |authorized|ACC-1598451071|153.41 -27.95|b4e02c10-0852-4273-b8fd-7b3395e32eb0|153.44 -28.06    |Mermaid Beach   |QLD  |700004     |
# |authorized|ACC-2776252858|144.95 -37.76|3aa18033-a0a9-4190-a117-b7caaf4d07e3|144.95 -37.53    |Kalkallo        |VIC  |700005     |
# |authorized|ACC-2776252858|144.95 -37.76|ee58145d-26e8-4b01-9cd9-62378014f21d|144.96 -37.81    |Melbourne       |VIC  |700006     |
# |authorized|ACC-182446574 |116.06 -32.00|cfbf535e-caa8-499f-9d41-bbdc2b836d85|115.85 -31.9     |Yokine          |WA   |700007     |
# |authorized|ACC-182446574 |116.06 -32.00|33952b07-859c-4c0a-8b1d-813a5f6b444c|115.86 -32.13    |Cockburn Central|WA   |700008     |
# |authorized|ACC-1903037542|153.05 -27.61|d920de7f-959c-4d9a-aee5-930689a2f8cd|152.94 -27.55    |Mount Ommaney   |QLD  |700009     |
# |authorized|ACC-4258502723|145.45 -37.74|b5565fff-0333-4c74-a61a-56a074d0ec0f|144.96 -37.78    |Brunswick       |VIC  |700010     |
# |authorized|ACC-1598451071|153.41 -27.95|f2ef6270-cf91-409f-a6a2-fbd6735ea500|153.6 -28.63     |Byron Bay       |NSW  |700011     |
# |authorized|ACC-2890243754|153.32 -27.93|7e8bf667-e724-4359-a406-3538a3e27b4e|153.28 -28.81    |Lismore         |NSW  |700012     |
# |authorized|ACC-3481401842|115.74 -31.72|38997041-c666-41a4-857b-9aaea10c008d|115.76 -32.06    |Fremantle       |WA   |700013     |
# |authorized|ACC-2615038700|145.35 -38.03|354f40cb-55bc-4a81-a00d-c7faede29f8b|145.09 -38.01    |Mordialloc      |VIC  |700014     |
# +----------+--------------+-------------+------------------------------------+-----------------+----------------+-----+-----------+
# only showing top 15 rows

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
